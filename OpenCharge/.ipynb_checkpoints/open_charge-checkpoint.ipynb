# %%
# Dependencies
import json
import requests
import os
import pandas as pd
import gmaps
import matplotlib.pyplot as plt
from oc_key import oc_key
from oc_key import g_key

gmaps.configure(api_key=g_key)

# %%
# Load city list csv
city_list_toload = "../Resources/weather_city_final.csv"

city_list_df = pd.read_csv(city_list_toload)
city_list_df
# Out:
#                  City_State      Clean_City  Population        Lat  \
# 0     Kansas City, Missouri     Kansas City    481417.0  39.099727
# 1           Omaha, Nebraska           Omaha    465112.0  41.256537
# 2         Lincoln, Nebraska         Lincoln    280849.0  40.813616
# 3       St. Louis, Missouri       St. Louis    311273.0  38.627003
# 4   Albuquerque, New Mexico     Albuquerque    559202.0  35.084386
# 5           Cleveland, Ohio       Cleveland    387398.0  41.499320
# 6   Oklahoma City, Oklahoma   Oklahoma City    637284.0  35.467560
# 7           Tulsa, Oklahoma           Tulsa    402223.0  36.153982
# 8          Portland, Oregon        Portland    639387.0  45.505106
# 9              Plano, Texas           Plano    284579.0  33.019843
# 10           Lubbock, Texas         Lubbock    250415.0  33.577863
# 11       San Antonio, Texas     San Antonio   1486521.0  29.424122
# 12            Dallas, Texas          Dallas   1318806.0  32.776664
# 13           El Paso, Texas         El Paso    680354.0  31.761878
# 14           Houston, Texas         Houston   2295982.0  29.760427
# 15    Corpus Christi, Texas  Corpus Christi    324692.0  27.800583
# 16        Fort Worth, Texas      Fort Worth    855786.0  32.755488
# 17            Austin, Texas          Austin    935755.0  30.267153
# 18         Arlington, Texas       Arlington    392462.0  32.735687
# 19     Milwaukee, Wisconsin       Milwaukee    596886.0  43.038902
# 20     Stockton, California        Stockton    306283.0  37.957702
# 21   Long Beach, California      Long Beach    468883.0  33.770050
# 22  Bakersfield, California     Bakersfield    375699.0  35.373292
# 23  Chula Vista, California     Chula Vista    266468.0  32.640054
# 24    San Diego, California       San Diego   1401932.0  32.715738
# 25      Anaheim, California         Anaheim    349668.0  33.836593
# 26       Fresno, California          Fresno    522277.0  36.737798
# 27      Oakland, California         Oakland    421042.0  37.804351
# 28         Aurora, Colorado          Aurora    363550.0  39.729432
# 29         Denver, Colorado          Denver    693417.0  39.739236
# 30       Irvine, California          Irvine    265502.0  33.684567
# 31     San Jose, California        San Jose   1026658.0  37.338208
# 32   Sacramento, California      Sacramento    495011.0  38.581572
# 33    Santa Ana, California       Santa Ana    333499.0  33.745472
# 34           Miami, Florida           Miami    451214.0  25.761680
# 35         Orlando, Florida         Orlando    275690.0  28.538335
# 36           Tampa, Florida           Tampa    376345.0  27.950575
# 37    Jacksonville, Florida    Jacksonville    878907.0  30.332184
# 38        Chicago, Illinois         Chicago   2718555.0  41.878114
# 39   New Orleans, Louisiana     New Orleans    389648.0  29.951066
# 40        Detroit, Michigan         Detroit    677155.0  42.331427
#
#            Lng  Max Temp  Min Temp
# 0   -94.578567     64.99     64.00
# 1   -95.934503     63.00     60.80
# 2   -96.702596     64.99     60.80
# 3   -90.199404     66.20     61.00
# 4  -106.650422     68.00     63.00
# 5   -81.694361     64.40     60.01
# 6   -97.516428     69.80     64.00
# 7   -95.992775     69.80     66.00
# 8  -122.675026     66.20     63.00
# 9   -96.698886     68.00     63.00
# 10 -101.855167     75.00     73.40
# 11  -98.493628     75.20     70.00
# 12  -96.796988     68.00     64.00
# 13 -106.485022     78.80     75.00
# 14  -95.369803     71.01     68.00
# 15  -97.396381     73.99     72.00
# 16  -97.330766     69.01     66.00
# 17  -97.743061     73.40     64.99
# 18  -97.108066     69.01     66.00
# 19  -87.906474     66.20     62.01
# 20 -121.290780     78.80     73.00
# 21 -118.193740     75.00     69.01
# 22 -119.018713     77.00     77.00
# 23 -117.084196     77.00     71.01
# 24 -117.161084     78.01     68.00
# 25 -117.914301     79.00     71.01
# 26 -119.787125     78.80     73.99
# 27 -122.271164     64.40     60.01
# 28 -104.831919     66.99     63.00
# 29 -104.990251     66.99     62.01
# 30 -117.826505     75.99     70.00
# 31 -121.886329     73.40     68.00
# 32 -121.494400     78.80     75.20
# 33 -117.867653     79.00     71.01
# 34  -80.191790     79.00     77.00
# 35  -81.379237     73.40     70.00
# 36  -82.457178     75.20     68.00
# 37  -81.655651     73.00     66.99
# 38  -87.629798     69.01     64.99
# 39  -90.071532     66.20     63.00
# 40  -83.045754     64.40     60.80

# %%
lats = city_list_df["Lat"].tolist()
longs = city_list_df["Lng"].tolist()
lats, longs
latlongpair = zip(lats,longs)
#latlongpair

# %%
print(latlongpair)
# Out:
# <zip object at 0x0000022004B75908>

# %%
# NEXT 5 Cells only used while testing my queries to the API - not needed in final

#latitude = 42.331427
#longitude = -83.045754

# %%
# Set the url for the Open Charge Map
#query_url = f"https://api.openchargemap.io/v3/poi/?output=json&client=DVProject1&countrycode=US&maxresults=500&distance=50&distanceunit=miles&verbose=false&compact=true&latitude={latitude}&longitude={longitude}&key={oc_key}"
#query_url = f"https://api.openchargemap.io/v3/poi/?output=json&client=DVProject1&countrycode=US&verbose=false&compact=true&latitude={latitude}&longitude={longitude}&key={oc_key}"


# Example url from API doc
#url = "https://api.openchargemap.io/v3/poi/?output=json&countrycode=US&maxresults=10&compact=true&verbose=false"

#print(query_url)

# %%
#charge_data = requests.get(query_url)
#print(charge_data.status_code)

# %%
#charge_json = charge_data.json()

#json.dumps(charge_json[0], indent=2)

# %%
#print(len(charge_json))

# %%
# list to capture station count per city
station_count = []

# Loop through each city and get a count of how many electric charge stations within 50 miles of center lat/long
for latlongpair in latlongpair:
    query_url = f"https://api.openchargemap.io/v3/poi/?output=json&client=DVProject1&countrycode=US&maxresults=3000&distance=50&distanceunit=miles&verbose=false&compact=true&latitude={latlongpair[0]}&longitude={latlongpair[1]}&key={oc_key}"
    charge_data = requests.get(query_url)
    charge_json = charge_data.json()
    station_count.append(len(charge_json))

# %%
station_count
# Out:
# [363,
#  45,
#  52,
#  117,
#  41,
#  134,
#  103,
#  86,
#  486,
#  612,
#  6,
#  148,
#  615,
#  47,
#  368,
#  25,
#  599,
#  384,
#  619,
#  123,
#  841,
#  2890,
#  55,
#  690,
#  700,
#  2966,
#  217,
#  1941,
#  546,
#  551,
#  2766,
#  1753,
#  609,
#  2834,
#  474,
#  445,
#  376,
#  143,
#  569,
#  67,
#  272]

# %%
# Add station count to the data frame and kick out a CSV
city_list_df["Number of Stations"] = station_count
#city_list_df.to_csv('Results/station_count_by_city.csv', index=False)
city_list_df
# Out:
#                  City_State      Clean_City  Population        Lat  \
# 0     Kansas City, Missouri     Kansas City    481417.0  39.099727
# 1           Omaha, Nebraska           Omaha    465112.0  41.256537
# 2         Lincoln, Nebraska         Lincoln    280849.0  40.813616
# 3       St. Louis, Missouri       St. Louis    311273.0  38.627003
# 4   Albuquerque, New Mexico     Albuquerque    559202.0  35.084386
# 5           Cleveland, Ohio       Cleveland    387398.0  41.499320
# 6   Oklahoma City, Oklahoma   Oklahoma City    637284.0  35.467560
# 7           Tulsa, Oklahoma           Tulsa    402223.0  36.153982
# 8          Portland, Oregon        Portland    639387.0  45.505106
# 9              Plano, Texas           Plano    284579.0  33.019843
# 10           Lubbock, Texas         Lubbock    250415.0  33.577863
# 11       San Antonio, Texas     San Antonio   1486521.0  29.424122
# 12            Dallas, Texas          Dallas   1318806.0  32.776664
# 13           El Paso, Texas         El Paso    680354.0  31.761878
# 14           Houston, Texas         Houston   2295982.0  29.760427
# 15    Corpus Christi, Texas  Corpus Christi    324692.0  27.800583
# 16        Fort Worth, Texas      Fort Worth    855786.0  32.755488
# 17            Austin, Texas          Austin    935755.0  30.267153
# 18         Arlington, Texas       Arlington    392462.0  32.735687
# 19     Milwaukee, Wisconsin       Milwaukee    596886.0  43.038902
# 20     Stockton, California        Stockton    306283.0  37.957702
# 21   Long Beach, California      Long Beach    468883.0  33.770050
# 22  Bakersfield, California     Bakersfield    375699.0  35.373292
# 23  Chula Vista, California     Chula Vista    266468.0  32.640054
# 24    San Diego, California       San Diego   1401932.0  32.715738
# 25      Anaheim, California         Anaheim    349668.0  33.836593
# 26       Fresno, California          Fresno    522277.0  36.737798
# 27      Oakland, California         Oakland    421042.0  37.804351
# 28         Aurora, Colorado          Aurora    363550.0  39.729432
# 29         Denver, Colorado          Denver    693417.0  39.739236
# 30       Irvine, California          Irvine    265502.0  33.684567
# 31     San Jose, California        San Jose   1026658.0  37.338208
# 32   Sacramento, California      Sacramento    495011.0  38.581572
# 33    Santa Ana, California       Santa Ana    333499.0  33.745472
# 34           Miami, Florida           Miami    451214.0  25.761680
# 35         Orlando, Florida         Orlando    275690.0  28.538335
# 36           Tampa, Florida           Tampa    376345.0  27.950575
# 37    Jacksonville, Florida    Jacksonville    878907.0  30.332184
# 38        Chicago, Illinois         Chicago   2718555.0  41.878114
# 39   New Orleans, Louisiana     New Orleans    389648.0  29.951066
# 40        Detroit, Michigan         Detroit    677155.0  42.331427
#
#            Lng  Max Temp  Min Temp  Number of Stations
# 0   -94.578567     64.99     64.00                 363
# 1   -95.934503     63.00     60.80                  45
# 2   -96.702596     64.99     60.80                  52
# 3   -90.199404     66.20     61.00                 117
# 4  -106.650422     68.00     63.00                  41
# 5   -81.694361     64.40     60.01                 134
# 6   -97.516428     69.80     64.00                 103
# 7   -95.992775     69.80     66.00                  86
# 8  -122.675026     66.20     63.00                 486
# 9   -96.698886     68.00     63.00                 612
# 10 -101.855167     75.00     73.40                   6
# 11  -98.493628     75.20     70.00                 148
# 12  -96.796988     68.00     64.00                 615
# 13 -106.485022     78.80     75.00                  47
# 14  -95.369803     71.01     68.00                 368
# 15  -97.396381     73.99     72.00                  25
# 16  -97.330766     69.01     66.00                 599
# 17  -97.743061     73.40     64.99                 384
# 18  -97.108066     69.01     66.00                 619
# 19  -87.906474     66.20     62.01                 123
# 20 -121.290780     78.80     73.00                 841
# 21 -118.193740     75.00     69.01                2890
# 22 -119.018713     77.00     77.00                  55
# 23 -117.084196     77.00     71.01                 690
# 24 -117.161084     78.01     68.00                 700
# 25 -117.914301     79.00     71.01                2966
# 26 -119.787125     78.80     73.99                 217
# 27 -122.271164     64.40     60.01                1941
# 28 -104.831919     66.99     63.00                 546
# 29 -104.990251     66.99     62.01                 551
# 30 -117.826505     75.99     70.00                2766
# 31 -121.886329     73.40     68.00                1753
# 32 -121.494400     78.80     75.20                 609
# 33 -117.867653     79.00     71.01                2834
# 34  -80.191790     79.00     77.00                 474
# 35  -81.379237     73.40     70.00                 445
# 36  -82.457178     75.20     68.00                 376
# 37  -81.655651     73.00     66.99                 143
# 38  -87.629798     69.01     64.99                 569
# 39  -90.071532     66.20     63.00                  67
# 40  -83.045754     64.40     60.80                 272

# %%
# Get stations per 1k pop data
pop1k = city_list_df["Population"]/1000

city_list_df["Stations per 1k Population"] = pop1k/station_count
#city_list_df.to_csv('Results/station_count_per1kpop.csv', index=False)
city_list_df
# Out:
#                  City_State      Clean_City  Population        Lat  \
# 0     Kansas City, Missouri     Kansas City    481417.0  39.099727
# 1           Omaha, Nebraska           Omaha    465112.0  41.256537
# 2         Lincoln, Nebraska         Lincoln    280849.0  40.813616
# 3       St. Louis, Missouri       St. Louis    311273.0  38.627003
# 4   Albuquerque, New Mexico     Albuquerque    559202.0  35.084386
# 5           Cleveland, Ohio       Cleveland    387398.0  41.499320
# 6   Oklahoma City, Oklahoma   Oklahoma City    637284.0  35.467560
# 7           Tulsa, Oklahoma           Tulsa    402223.0  36.153982
# 8          Portland, Oregon        Portland    639387.0  45.505106
# 9              Plano, Texas           Plano    284579.0  33.019843
# 10           Lubbock, Texas         Lubbock    250415.0  33.577863
# 11       San Antonio, Texas     San Antonio   1486521.0  29.424122
# 12            Dallas, Texas          Dallas   1318806.0  32.776664
# 13           El Paso, Texas         El Paso    680354.0  31.761878
# 14           Houston, Texas         Houston   2295982.0  29.760427
# 15    Corpus Christi, Texas  Corpus Christi    324692.0  27.800583
# 16        Fort Worth, Texas      Fort Worth    855786.0  32.755488
# 17            Austin, Texas          Austin    935755.0  30.267153
# 18         Arlington, Texas       Arlington    392462.0  32.735687
# 19     Milwaukee, Wisconsin       Milwaukee    596886.0  43.038902
# 20     Stockton, California        Stockton    306283.0  37.957702
# 21   Long Beach, California      Long Beach    468883.0  33.770050
# 22  Bakersfield, California     Bakersfield    375699.0  35.373292
# 23  Chula Vista, California     Chula Vista    266468.0  32.640054
# 24    San Diego, California       San Diego   1401932.0  32.715738
# 25      Anaheim, California         Anaheim    349668.0  33.836593
# 26       Fresno, California          Fresno    522277.0  36.737798
# 27      Oakland, California         Oakland    421042.0  37.804351
# 28         Aurora, Colorado          Aurora    363550.0  39.729432
# 29         Denver, Colorado          Denver    693417.0  39.739236
# 30       Irvine, California          Irvine    265502.0  33.684567
# 31     San Jose, California        San Jose   1026658.0  37.338208
# 32   Sacramento, California      Sacramento    495011.0  38.581572
# 33    Santa Ana, California       Santa Ana    333499.0  33.745472
# 34           Miami, Florida           Miami    451214.0  25.761680
# 35         Orlando, Florida         Orlando    275690.0  28.538335
# 36           Tampa, Florida           Tampa    376345.0  27.950575
# 37    Jacksonville, Florida    Jacksonville    878907.0  30.332184
# 38        Chicago, Illinois         Chicago   2718555.0  41.878114
# 39   New Orleans, Louisiana     New Orleans    389648.0  29.951066
# 40        Detroit, Michigan         Detroit    677155.0  42.331427
#
#            Lng  Max Temp  Min Temp  Number of Stations  \
# 0   -94.578567     64.99     64.00                 363
# 1   -95.934503     63.00     60.80                  45
# 2   -96.702596     64.99     60.80                  52
# 3   -90.199404     66.20     61.00                 117
# 4  -106.650422     68.00     63.00                  41
# 5   -81.694361     64.40     60.01                 134
# 6   -97.516428     69.80     64.00                 103
# 7   -95.992775     69.80     66.00                  86
# 8  -122.675026     66.20     63.00                 486
# 9   -96.698886     68.00     63.00                 612
# 10 -101.855167     75.00     73.40                   6
# 11  -98.493628     75.20     70.00                 148
# 12  -96.796988     68.00     64.00                 615
# 13 -106.485022     78.80     75.00                  47
# 14  -95.369803     71.01     68.00                 368
# 15  -97.396381     73.99     72.00                  25
# 16  -97.330766     69.01     66.00                 599
# 17  -97.743061     73.40     64.99                 384
# 18  -97.108066     69.01     66.00                 619
# 19  -87.906474     66.20     62.01                 123
# 20 -121.290780     78.80     73.00                 841
# 21 -118.193740     75.00     69.01                2890
# 22 -119.018713     77.00     77.00                  55
# 23 -117.084196     77.00     71.01                 690
# 24 -117.161084     78.01     68.00                 700
# 25 -117.914301     79.00     71.01                2966
# 26 -119.787125     78.80     73.99                 217
# 27 -122.271164     64.40     60.01                1941
# 28 -104.831919     66.99     63.00                 546
# 29 -104.990251     66.99     62.01                 551
# 30 -117.826505     75.99     70.00                2766
# 31 -121.886329     73.40     68.00                1753
# 32 -121.494400     78.80     75.20                 609
# 33 -117.867653     79.00     71.01                2834
# 34  -80.191790     79.00     77.00                 474
# 35  -81.379237     73.40     70.00                 445
# 36  -82.457178     75.20     68.00                 376
# 37  -81.655651     73.00     66.99                 143
# 38  -87.629798     69.01     64.99                 569
# 39  -90.071532     66.20     63.00                  67
# 40  -83.045754     64.40     60.80                 272
#
#     Stations per 1k Population
# 0                     1.326218
# 1                    10.335822
# 2                     5.400942
# 3                     2.660453
# 4                    13.639073
# 5                     2.891030
# 6                     6.187223
# 7                     4.677012
# 8                     1.315611
# 9                     0.464998
# 10                   41.735833
# 11                   10.044061
# 12                    2.144400
# 13                   14.475617
# 14                    6.239082
# 15                   12.987680
# 16                    1.428691
# 17                    2.436862
# 18                    0.634026
# 19                    4.852732
# 20                    0.364189
# 21                    0.162243
# 22                    6.830891
# 23                    0.386186
# 24                    2.002760
# 25                    0.117892
# 26                    2.406806
# 27                    0.216920
# 28                    0.665842
# 29                    1.258470
# 30                    0.095988
# 31                    0.585658
# 32                    0.812826
# 33                    0.117678
# 34                    0.951928
# 35                    0.619528
# 36                    1.000918
# 37                    6.146203
# 38                    4.777777
# 39                    5.815642
# 40                    2.489540

# %%
# Get stations per mile using area of 50-mile radius circle, 7,854 miles
permile = city_list_df["Number of Stations"]

city_list_df["Stations per mile"] = (city_list_df["Number of Stations"])/7854
#city_list_df.to_csv('Results/station_count_permile.csv', index=False)
city_list_df
# Out:
#                  City_State      Clean_City  Population        Lat  \
# 0     Kansas City, Missouri     Kansas City    481417.0  39.099727
# 1           Omaha, Nebraska           Omaha    465112.0  41.256537
# 2         Lincoln, Nebraska         Lincoln    280849.0  40.813616
# 3       St. Louis, Missouri       St. Louis    311273.0  38.627003
# 4   Albuquerque, New Mexico     Albuquerque    559202.0  35.084386
# 5           Cleveland, Ohio       Cleveland    387398.0  41.499320
# 6   Oklahoma City, Oklahoma   Oklahoma City    637284.0  35.467560
# 7           Tulsa, Oklahoma           Tulsa    402223.0  36.153982
# 8          Portland, Oregon        Portland    639387.0  45.505106
# 9              Plano, Texas           Plano    284579.0  33.019843
# 10           Lubbock, Texas         Lubbock    250415.0  33.577863
# 11       San Antonio, Texas     San Antonio   1486521.0  29.424122
# 12            Dallas, Texas          Dallas   1318806.0  32.776664
# 13           El Paso, Texas         El Paso    680354.0  31.761878
# 14           Houston, Texas         Houston   2295982.0  29.760427
# 15    Corpus Christi, Texas  Corpus Christi    324692.0  27.800583
# 16        Fort Worth, Texas      Fort Worth    855786.0  32.755488
# 17            Austin, Texas          Austin    935755.0  30.267153
# 18         Arlington, Texas       Arlington    392462.0  32.735687
# 19     Milwaukee, Wisconsin       Milwaukee    596886.0  43.038902
# 20     Stockton, California        Stockton    306283.0  37.957702
# 21   Long Beach, California      Long Beach    468883.0  33.770050
# 22  Bakersfield, California     Bakersfield    375699.0  35.373292
# 23  Chula Vista, California     Chula Vista    266468.0  32.640054
# 24    San Diego, California       San Diego   1401932.0  32.715738
# 25      Anaheim, California         Anaheim    349668.0  33.836593
# 26       Fresno, California          Fresno    522277.0  36.737798
# 27      Oakland, California         Oakland    421042.0  37.804351
# 28         Aurora, Colorado          Aurora    363550.0  39.729432
# 29         Denver, Colorado          Denver    693417.0  39.739236
# 30       Irvine, California          Irvine    265502.0  33.684567
# 31     San Jose, California        San Jose   1026658.0  37.338208
# 32   Sacramento, California      Sacramento    495011.0  38.581572
# 33    Santa Ana, California       Santa Ana    333499.0  33.745472
# 34           Miami, Florida           Miami    451214.0  25.761680
# 35         Orlando, Florida         Orlando    275690.0  28.538335
# 36           Tampa, Florida           Tampa    376345.0  27.950575
# 37    Jacksonville, Florida    Jacksonville    878907.0  30.332184
# 38        Chicago, Illinois         Chicago   2718555.0  41.878114
# 39   New Orleans, Louisiana     New Orleans    389648.0  29.951066
# 40        Detroit, Michigan         Detroit    677155.0  42.331427
#
#            Lng  Max Temp  Min Temp  Number of Stations  \
# 0   -94.578567     64.99     64.00                 363
# 1   -95.934503     63.00     60.80                  45
# 2   -96.702596     64.99     60.80                  52
# 3   -90.199404     66.20     61.00                 117
# 4  -106.650422     68.00     63.00                  41
# 5   -81.694361     64.40     60.01                 134
# 6   -97.516428     69.80     64.00                 103
# 7   -95.992775     69.80     66.00                  86
# 8  -122.675026     66.20     63.00                 486
# 9   -96.698886     68.00     63.00                 612
# 10 -101.855167     75.00     73.40                   6
# 11  -98.493628     75.20     70.00                 148
# 12  -96.796988     68.00     64.00                 615
# 13 -106.485022     78.80     75.00                  47
# 14  -95.369803     71.01     68.00                 368
# 15  -97.396381     73.99     72.00                  25
# 16  -97.330766     69.01     66.00                 599
# 17  -97.743061     73.40     64.99                 384
# 18  -97.108066     69.01     66.00                 619
# 19  -87.906474     66.20     62.01                 123
# 20 -121.290780     78.80     73.00                 841
# 21 -118.193740     75.00     69.01                2890
# 22 -119.018713     77.00     77.00                  55
# 23 -117.084196     77.00     71.01                 690
# 24 -117.161084     78.01     68.00                 700
# 25 -117.914301     79.00     71.01                2966
# 26 -119.787125     78.80     73.99                 217
# 27 -122.271164     64.40     60.01                1941
# 28 -104.831919     66.99     63.00                 546
# 29 -104.990251     66.99     62.01                 551
# 30 -117.826505     75.99     70.00                2766
# 31 -121.886329     73.40     68.00                1753
# 32 -121.494400     78.80     75.20                 609
# 33 -117.867653     79.00     71.01                2834
# 34  -80.191790     79.00     77.00                 474
# 35  -81.379237     73.40     70.00                 445
# 36  -82.457178     75.20     68.00                 376
# 37  -81.655651     73.00     66.99                 143
# 38  -87.629798     69.01     64.99                 569
# 39  -90.071532     66.20     63.00                  67
# 40  -83.045754     64.40     60.80                 272
#
#     Stations per 1k Population  Stations per mile
# 0                     1.326218           0.046218
# 1                    10.335822           0.005730
# 2                     5.400942           0.006621
# 3                     2.660453           0.014897
# 4                    13.639073           0.005220
# 5                     2.891030           0.017061
# 6                     6.187223           0.013114
# 7                     4.677012           0.010950
# 8                     1.315611           0.061879
# 9                     0.464998           0.077922
# 10                   41.735833           0.000764
# 11                   10.044061           0.018844
# 12                    2.144400           0.078304
# 13                   14.475617           0.005984
# 14                    6.239082           0.046855
# 15                   12.987680           0.003183
# 16                    1.428691           0.076267
# 17                    2.436862           0.048892
# 18                    0.634026           0.078813
# 19                    4.852732           0.015661
# 20                    0.364189           0.107079
# 21                    0.162243           0.367965
# 22                    6.830891           0.007003
# 23                    0.386186           0.087853
# 24                    2.002760           0.089127
# 25                    0.117892           0.377642
# 26                    2.406806           0.027629
# 27                    0.216920           0.247135
# 28                    0.665842           0.069519
# 29                    1.258470           0.070155
# 30                    0.095988           0.352177
# 31                    0.585658           0.223198
# 32                    0.812826           0.077540
# 33                    0.117678           0.360835
# 34                    0.951928           0.060351
# 35                    0.619528           0.056659
# 36                    1.000918           0.047874
# 37                    6.146203           0.018207
# 38                    4.777777           0.072447
# 39                    5.815642           0.008531
# 40                    2.489540           0.034632

# %%
#city_list_df["Stations per 10 miles"] = (city_list_df["Number of Stations"])/785.4
#city_list_df

# %%
city_list_df = city_list_df.sort_values("Number of Stations", ascending=False)
city_list_df.to_csv('Results/citylist_sorted_stationct.csv', index=False)
city_list_df.head(20)
# Out:
#                  City_State   Clean_City  Population        Lat         Lng  \
# 25      Anaheim, California      Anaheim    349668.0  33.836593 -117.914301
# 21   Long Beach, California   Long Beach    468883.0  33.770050 -118.193740
# 33    Santa Ana, California    Santa Ana    333499.0  33.745472 -117.867653
# 30       Irvine, California       Irvine    265502.0  33.684567 -117.826505
# 27      Oakland, California      Oakland    421042.0  37.804351 -122.271164
# 31     San Jose, California     San Jose   1026658.0  37.338208 -121.886329
# 20     Stockton, California     Stockton    306283.0  37.957702 -121.290780
# 24    San Diego, California    San Diego   1401932.0  32.715738 -117.161084
# 23  Chula Vista, California  Chula Vista    266468.0  32.640054 -117.084196
# 18         Arlington, Texas    Arlington    392462.0  32.735687  -97.108066
# 12            Dallas, Texas       Dallas   1318806.0  32.776664  -96.796988
# 9              Plano, Texas        Plano    284579.0  33.019843  -96.698886
# 32   Sacramento, California   Sacramento    495011.0  38.581572 -121.494400
# 16        Fort Worth, Texas   Fort Worth    855786.0  32.755488  -97.330766
# 38        Chicago, Illinois      Chicago   2718555.0  41.878114  -87.629798
# 29         Denver, Colorado       Denver    693417.0  39.739236 -104.990251
# 28         Aurora, Colorado       Aurora    363550.0  39.729432 -104.831919
# 8          Portland, Oregon     Portland    639387.0  45.505106 -122.675026
# 34           Miami, Florida        Miami    451214.0  25.761680  -80.191790
# 35         Orlando, Florida      Orlando    275690.0  28.538335  -81.379237
#
#     Max Temp  Min Temp  Number of Stations  Stations per 1k Population  \
# 25     79.00     71.01                2966                    0.117892
# 21     75.00     69.01                2890                    0.162243
# 33     79.00     71.01                2834                    0.117678
# 30     75.99     70.00                2766                    0.095988
# 27     64.40     60.01                1941                    0.216920
# 31     73.40     68.00                1753                    0.585658
# 20     78.80     73.00                 841                    0.364189
# 24     78.01     68.00                 700                    2.002760
# 23     77.00     71.01                 690                    0.386186
# 18     69.01     66.00                 619                    0.634026
# 12     68.00     64.00                 615                    2.144400
# 9      68.00     63.00                 612                    0.464998
# 32     78.80     75.20                 609                    0.812826
# 16     69.01     66.00                 599                    1.428691
# 38     69.01     64.99                 569                    4.777777
# 29     66.99     62.01                 551                    1.258470
# 28     66.99     63.00                 546                    0.665842
# 8      66.20     63.00                 486                    1.315611
# 34     79.00     77.00                 474                    0.951928
# 35     73.40     70.00                 445                    0.619528
#
#     Stations per mile
# 25           0.377642
# 21           0.367965
# 33           0.360835
# 30           0.352177
# 27           0.247135
# 31           0.223198
# 20           0.107079
# 24           0.089127
# 23           0.087853
# 18           0.078813
# 12           0.078304
# 9            0.077922
# 32           0.077540
# 16           0.076267
# 38           0.072447
# 29           0.070155
# 28           0.069519
# 8            0.061879
# 34           0.060351
# 35           0.056659

# %%
# Set up a heat map for charging stations
locations = city_list_df[["Lat","Lng"]]
stationct = city_list_df["Number of Stations"].astype(float)
stationspermile = city_list_df["Stations per mile"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=stationct, dissipating=False, max_intensity=750, point_radius=2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Set up a heat map for charging stations per 1k pop
locations = city_list_df[["Lat","Lng"]]
stationct = city_list_df["Number of Stations"].astype(float)
stationper1k = city_list_df["Stations per 1k Population"].astype(float)

# %%
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=stationspermile, dissipating=False, max_intensity=.30, point_radius=2)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
stations = city_list_df["Number of Stations"].tolist()
latitudes = city_list_df["Lat"].tolist()
population = city_list_df["Population"].tolist()
stations_mile = city_list_df["Stations per mile"].tolist()
maxtemp = city_list_df["Max Temp"].tolist()

#Doesn't show much
#plt.scatter(stations, population)
#plt.grid(True)
#plt.show()

# %%
plt.hist(stations, bins=12, color='green')
plt.ylabel("Number of Cities")
plt.xlabel("Station Count")
plt.title("How many cities have widespread charging infrastructure?")
plt.grid(True)
plt.savefig("Results/station_ct_by_cities.png")
plt.show()

# %%
# Generate a figure comparing station count to population
fig, ax1 = plt.subplots(figsize=(18,5))

color = 'tab:red'
#ax1.set_xlabel("City")
ax1.set_ylabel("Stations", color=color)
ax1.plot(city_list_df["Clean_City"], stations, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='x', labelrotation=90)

ax2 = ax1.twinx()

color = 'tab:blue'
ax2.set_ylabel('Population', color=color)
ax2.plot(city_list_df["Clean_City"], population, color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.ticklabel_format(axis='y', style='plain')

fig.tight_layout()
plt.savefig("Results/stations_v_population.png")
plt.show()

# %%
# Stations per mile graphic
plt.figure(figsize=(18,8))
plt.bar(city_list_df["Clean_City"], city_list_df["Stations per mile"])
plt.xticks(rotation=75)
plt.savefig("Results/stations_per_mile.png")
plt.show()

# %%
station_corr = city_list_df.corr()
station_corr.unstack().sort_values()
# Out:
# Number of Stations          Lng                          -0.543813
# Lng                         Number of Stations           -0.543813
# Stations per mile           Lng                          -0.543813
# Lng                         Stations per mile            -0.543813
# Max Temp                    Lat                          -0.541490
#                                                             ...
# Lat                         Lat                           1.000000
# Stations per 1k Population  Stations per 1k Population    1.000000
# Stations per mile           Stations per mile             1.000000
# Number of Stations          Stations per mile             1.000000
# Stations per mile           Number of Stations            1.000000
# Length: 64, dtype: float64

# %%
# THIS WAS A BAD IDEA - poi.json is WAY too big...


#filepath = os.path.join("Resources", "poi.json")
#with open(filepath, encoding="utf8") as jsonfile:
#    open_charge = json.load(jsonfile)

# %%
# THIS WAS ALL WORKING WITH THE FULL DATA SET BUT THERE'S a CHAR ISSUE SOMEWHERE

#js = [json.loads(line) for line in open(filepath, encoding="utf8")]
#for item in js:
    #name = item.get("name")
    #businessID = item.get("business_id")

# %%
#filepath = os.path.join("Resources", "poi.json")

#print(json.dumps(filepath, encoding="utf8", indent=4, sort_keys=True))
