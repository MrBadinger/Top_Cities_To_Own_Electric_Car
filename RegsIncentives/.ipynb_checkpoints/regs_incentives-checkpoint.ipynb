# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load regs and incentives list csv
reg_incent_toload = "../Resources/ev_incentives_by_state.csv"

reg_incent_df = pd.read_csv(reg_incent_toload)
reg_incent_df
# Out:
#             Jurisdiction  Incentives Registrations
# 0                Alabama           6         1,450
# 1                 Alaska           1           530
# 2                Arizona          19        15,000
# 3               Arkansas           4           520
# 4             California         104       256,800
# 5               Colorado          35        11,700
# 6            Connecticut          24         4,450
# 7               Delaware          10           720
# 8   District of Columbia          11           970
# 9                Florida          13        25,200
# 10               Georgia           6        15,300
# 11                Hawaii          12         6,590
# 12                 Idaho           7         1,080
# 13              Illinois          14        12,400
# 14               Indiana           8         3,030
# 15                  Iowa          14         1,090
# 16                Kansas           2         1,610
# ...

# %%
incentives = reg_incent_df["Incentives"].tolist()
registrations = reg_incent_df["Registrations"].tolist()
